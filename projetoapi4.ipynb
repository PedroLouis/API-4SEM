# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroLouis/API-4SEM/blob/main/projetoapi4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from google.colab import drive
drive.mount('/content/drive')

path_in = '/content/drive/My Drive/Data/'
path_out = '/content/drive/My Drive/Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file1 = path_in + '2014Atracacao.txt'
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file2 = path_in + '2015Atracacao.txt'
df2 = pd.read_csv(file2, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file3 = path_in + '2016Atracacao.txt'
df3 = pd.read_csv(file3, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file4 = path_in + '2017Atracacao.txt'
df4 = pd.read_csv(file4, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file5 = path_in + '2018Atracacao.txt'
df5 = pd.read_csv(file5, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file6 = path_in + '2019Atracacao.txt'
df6 = pd.read_csv(file6, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file7 = path_in + '2020Atracacao.txt'
df7 = pd.read_csv(file7, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file8 = path_in + '2021Atracacao.txt'
df8 = pd.read_csv(file8, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file9 = path_in + '2022Atracacao.txt'
df9 = pd.read_csv(file9, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

file10 = path_in + '2023Atracacao.txt'
df10 = pd.read_csv(file10, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

# %%
csv_final = [file1, file2, file3, file4, file5, file6, file7, file8, file9, file10]
ANTAQ_Int = pd.DataFrame()
for csv_final in csv_final:
    df = pd.read_csv(csv_final, sep = ';')
    ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True)
ANTAQ_Int.info()
# Out:
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <ipython-input-29-d9dd76df2ae5>:4: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_final, sep = ';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776110 entries, 0 to 776109
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     776110 non-null  int64
#  1   CDTUP                           776110 non-null  object
#  2   IDBerco                         773456 non-null  object
#  3   Berço                           773324 non-null  object
#  4   Porto Atracação                 773456 non-null  object
#  5   Coordenadas                     773320 non-null  object
#  6   Apelido Instalação Portuária    282346 non-null  object
#  7   Complexo Portuário              776110 non-null  object
#  8   Tipo da Autoridade Portuária    776110 non-null  object
#  9   Data Atracação                  773456 non-null  object
#  10  Data Chegada                    773456 non-null  object
#  11  Data Desatracação               776110 non-null  object
#  12  Data Início Operação            737365 non-null  object
#  13  Data Término Operação           737333 non-null  object
#  14  Ano                             776110 non-null  int64
#  15  Mes                             776110 non-null  object
#  16  Tipo de Operação                773456 non-null  object
#  17  Tipo de Navegação da Atracação  773456 non-null  object
#  18  Nacionalidade do Armador        773456 non-null  float64
#  19  FlagMCOperacaoAtracacao         776110 non-null  int64
#  20  Terminal                        773324 non-null  object
#  21  Município                       773324 non-null  object
#  22  UF                              773324 non-null  object
#  23  SGUF                            773324 non-null  object
#  24  Região Geográfica               773324 non-null  object
#  25  Nº da Capitania                 444671 non-null  object
#  26  Nº do IMO                       436984 non-null  float64
# dtypes: float64(2), int64(3), object(22)
# memory usage: 159.9+ MB

# %%
#checagem das colunas do dataframe
ANTAQ_Int.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco                Berço  \
# 0       658190  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 1       658182  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 2       658189  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 3          247       BR          NaN                  NaN
# 4       645614  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
#
#                Porto Atracação     Coordenadas Apelido Instalação Portuária  \
# 0  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 1  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 2  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 3                          NaN             NaN                          NaN
# 4  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
#
#   Complexo Portuário Tipo da Autoridade Portuária       Data Atracação  \
# 0             Manaus          Terminal Autorizado  10/12/2014 12:44:00
# 1             Manaus          Terminal Autorizado  12/12/2014 20:56:00
# 2             Manaus          Terminal Autorizado  10/12/2014 12:44:00
# 3   Não Classificado             Porto Organizado                  NaN
# 4             Manaus          Terminal Autorizado  20/10/2014 18:20:00
#
#           Data Chegada    Data Desatracação Data Início Operação  \
# 0  10/12/2014 12:44:00  10/12/2014 15:00:00  10/12/2014 12:44:00
# 1  12/12/2014 20:56:00  12/12/2014 23:08:00  12/12/2014 20:56:00
# 2  10/12/2014 12:44:00  10/12/2014 15:00:00  10/12/2014 12:44:00
# 3                  NaN  01/07/2014 00:00:00                  NaN
# 4  20/10/2014 18:20:00  20/10/2014 19:58:00  20/10/2014 18:20:00
#
#   Data Término Operação   Ano  Mes       Tipo de Operação  \
# 0   10/12/2014 15:00:00  2014  dez  Movimentação da Carga
# 1   12/12/2014 23:08:00  2014  dez  Movimentação da Carga
# 2   10/12/2014 15:00:00  2014  dez  Movimentação da Carga
# 3                   NaN  2014  jul                    NaN
# 4   20/10/2014 19:58:00  2014  out  Movimentação da Carga
#
#   Tipo de Navegação da Atracação  Nacionalidade do Armador  \
# 0                       Interior                       1.0
# 1                       Interior                       1.0
# 2                       Interior                       1.0
# 3                            NaN                       NaN
# 4                       Interior                       1.0
#
#    FlagMCOperacaoAtracacao                     Terminal    Município  \
# 0                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 1                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 2                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 3                        1                          NaN          NaN
# 4                        1  Terminal Graneleiro Hermasa  Itacoatiara
#
#          UF SGUF Região Geográfica Nº da Capitania  Nº do IMO
# 0  Amazonas   AM             Norte             NaN        NaN
# 1  Amazonas   AM             Norte             NaN        NaN
# 2  Amazonas   AM             Norte             NaN        NaN
# 3       NaN  NaN               NaN             NaN        NaN
# 4  Amazonas   AM             Norte             NaN        NaN

# %%
colunas_interesse = ['IDBerco','Data Atracação', 'Data Chegada',
                     'Data Desatracação', 'Data Início Operação',
                     'Data Término Operação']
ANTAQ_Limpa = ANTAQ_Int.dropna(subset=colunas_interesse)
ANTAQ_Limpa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737292 entries, 0 to 776106
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     737292 non-null  int64
#  1   CDTUP                           737292 non-null  object
#  2   IDBerco                         737292 non-null  object
#  3   Berço                           737201 non-null  object
#  4   Porto Atracação                 737292 non-null  object
#  5   Coordenadas                     737159 non-null  object
#  6   Apelido Instalação Portuária    271900 non-null  object
#  7   Complexo Portuário              737292 non-null  object
#  8   Tipo da Autoridade Portuária    737292 non-null  object
#  9   Data Atracação                  737292 non-null  object
#  10  Data Chegada                    737292 non-null  object
#  11  Data Desatracação               737292 non-null  object
#  12  Data Início Operação            737292 non-null  object
#  13  Data Término Operação           737292 non-null  object
#  14  Ano                             737292 non-null  int64
#  15  Mes                             737292 non-null  object
#  16  Tipo de Operação                737292 non-null  object
#  17  Tipo de Navegação da Atracação  737292 non-null  object
#  18  Nacionalidade do Armador        737292 non-null  float64
#  19  FlagMCOperacaoAtracacao         737292 non-null  int64
#  20  Terminal                        737201 non-null  object
#  21  Município                       737201 non-null  object
#  22  UF                              737201 non-null  object
#  23  SGUF                            737201 non-null  object
#  24  Região Geográfica               737201 non-null  object
#  25  Nº da Capitania                 422172 non-null  object
#  26  Nº do IMO                       412337 non-null  float64
# dtypes: float64(2), int64(3), object(22)
# memory usage: 157.5+ MB

# %%
ANTAQ_Limpa.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco                Berço  \
# 0       658190  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 1       658182  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 2       658189  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 4       645614  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 5       634095  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
#
#                Porto Atracação     Coordenadas Apelido Instalação Portuária  \
# 0  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 1  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 2  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 4  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
# 5  Terminal Graneleiro Hermasa  -58.484,-3.136                          NaN
#
#   Complexo Portuário Tipo da Autoridade Portuária       Data Atracação  \
# 0             Manaus          Terminal Autorizado  10/12/2014 12:44:00
# 1             Manaus          Terminal Autorizado  12/12/2014 20:56:00
# 2             Manaus          Terminal Autorizado  10/12/2014 12:44:00
# 4             Manaus          Terminal Autorizado  20/10/2014 18:20:00
# 5             Manaus          Terminal Autorizado  29/08/2014 13:44:00
#
#           Data Chegada    Data Desatracação Data Início Operação  \
# 0  10/12/2014 12:44:00  10/12/2014 15:00:00  10/12/2014 12:44:00
# 1  12/12/2014 20:56:00  12/12/2014 23:08:00  12/12/2014 20:56:00
# 2  10/12/2014 12:44:00  10/12/2014 15:00:00  10/12/2014 12:44:00
# 4  20/10/2014 18:20:00  20/10/2014 19:58:00  20/10/2014 18:20:00
# 5  29/08/2014 13:44:00  29/08/2014 15:36:00  29/08/2014 13:44:00
#
#   Data Término Operação   Ano  Mes       Tipo de Operação  \
# 0   10/12/2014 15:00:00  2014  dez  Movimentação da Carga
# 1   12/12/2014 23:08:00  2014  dez  Movimentação da Carga
# 2   10/12/2014 15:00:00  2014  dez  Movimentação da Carga
# 4   20/10/2014 19:58:00  2014  out  Movimentação da Carga
# 5   29/08/2014 15:36:00  2014  ago  Movimentação da Carga
#
#   Tipo de Navegação da Atracação  Nacionalidade do Armador  \
# 0                       Interior                       1.0
# 1                       Interior                       1.0
# 2                       Interior                       1.0
# 4                       Interior                       1.0
# 5                       Interior                       1.0
#
#    FlagMCOperacaoAtracacao                     Terminal    Município  \
# 0                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 1                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 2                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 4                        1  Terminal Graneleiro Hermasa  Itacoatiara
# 5                        1  Terminal Graneleiro Hermasa  Itacoatiara
#
#          UF SGUF Região Geográfica Nº da Capitania  Nº do IMO
# 0  Amazonas   AM             Norte             NaN        NaN
# 1  Amazonas   AM             Norte             NaN        NaN
# 2  Amazonas   AM             Norte             NaN        NaN
# 4  Amazonas   AM             Norte             NaN        NaN
# 5  Amazonas   AM             Norte             NaN        NaN

# %%
ANTAQ_Limpa['Data Chegada'] = pd.to_datetime(ANTAQ_Limpa['Data Chegada'], format='%d/%m/%Y %H:%M:%S')
ANTAQ_Limpa['Data Atracação'] = pd.to_datetime(ANTAQ_Limpa['Data Atracação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ_Limpa['Data Início Operação'] = pd.to_datetime(ANTAQ_Limpa['Data Início Operação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ_Limpa['Data Término Operação'] = pd.to_datetime(ANTAQ_Limpa['Data Término Operação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ_Limpa['Data Desatracação'] = pd.to_datetime(ANTAQ_Limpa['Data Desatracação'], format='%d/%m/%Y %H:%M:%S')
# Out:
# <ipython-input-33-a3e8f99cc46e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Data Chegada'] = pd.to_datetime(ANTAQ_Limpa['Data Chegada'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-33-a3e8f99cc46e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Data Atracação'] = pd.to_datetime(ANTAQ_Limpa['Data Atracação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-33-a3e8f99cc46e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Data Início Operação'] = pd.to_datetime(ANTAQ_Limpa['Data Início Operação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-33-a3e8f99cc46e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Data Término Operação'] = pd.to_datetime(ANTAQ_Limpa['Data Término Operação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-33-a3e8f99cc46e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Data Desatracação'] = pd.to_datetime(ANTAQ_Limpa['Data Desatracação'], format='%d/%m/%Y %H:%M:%S')

# %%
ANTAQ_Limpa['Tempo_espera_chegada'] = (ANTAQ_Limpa['Data Atracação'] - ANTAQ_Limpa['Data Chegada']).dt.total_seconds() / 3600
ANTAQ_Limpa['Tempo_espera_inicial'] = (ANTAQ_Limpa['Data Início Operação'] - ANTAQ_Limpa['Data Atracação']).dt.total_seconds() / 3600
ANTAQ_Limpa['Tempo_operacao'] = (ANTAQ_Limpa['Data Término Operação'] - ANTAQ_Limpa['Data Início Operação']).dt.total_seconds() / 3600
ANTAQ_Limpa['Tempo_espera_final'] = (ANTAQ_Limpa['Data Desatracação'] - ANTAQ_Limpa['Data Término Operação']).dt.total_seconds() / 3600
ANTAQ_Limpa['Tempo_ocupacao'] = (ANTAQ_Limpa['Data Desatracação'] - ANTAQ_Limpa['Data Atracação']).dt.total_seconds() / 3600
# Out:
# <ipython-input-35-8d6d5b20b452>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Tempo_espera_chegada'] = (ANTAQ_Limpa['Data Atracação'] - ANTAQ_Limpa['Data Chegada']).dt.total_seconds() / 3600
# <ipython-input-35-8d6d5b20b452>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Tempo_espera_inicial'] = (ANTAQ_Limpa['Data Início Operação'] - ANTAQ_Limpa['Data Atracação']).dt.total_seconds() / 3600
# <ipython-input-35-8d6d5b20b452>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Tempo_operacao'] = (ANTAQ_Limpa['Data Término Operação'] - ANTAQ_Limpa['Data Início Operação']).dt.total_seconds() / 3600
# <ipython-input-35-8d6d5b20b452>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Tempo_espera_final'] = (ANTAQ_Limpa['Data Desatracação'] - ANTAQ_Limpa['Data Término Operação']).dt.total_seconds() / 3600
# <ipython-input-35-8d6d5b20b452>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ_Limpa['Tempo_ocupacao'] = (ANTAQ_Limpa['Data Desatracação'] - ANTAQ_Limpa['Data Atracação']).dt.total_seconds() / 3600

# %%
duplicados = ANTAQ_Limpa.duplicated(subset=['IDAtracacao'], keep=False)
if duplicados.any():
    print("Existem valores duplicados.")
    print(ANTAQ_Limpa[duplicados])
else:
    print("Coluna com valores unicos.")
# Out:
# Coluna com valores unicos.

# %%
coluna = 'Complexo Portuário'
CP = ANTAQ_Limpa[coluna].value_counts().sort_index()
print(f"Total de operações {coluna}:")
print(CP)
# Out:
# Total de operações Complexo Portuário:
# Complexo Portuário
# Almeirim                                  285
# Angra dos Reis                           4372
# Aracajú                                  3877
# Aratu - Salvador                        20133
# Areia Branca                            19854
# Barra do Riacho                          7744
# Cabedelo (Instalação Isolada)            1091
# Coari (Instalação Isolada)               4384
# Corumbá                                 22210
# Estrela                                     9
# Forno                                     857
# Ilhéus                                   4663
# Imbituba                                 2642
# Itaguaí                                 10577
# Itaituba                                19164
# Itajaí                                   9636
# Itaqui                                  18886
# LDC Pederneiras (Instalação Isolada)     2908
# Macapá                                   3362
# Maceió                                   3285
# Manaus                                  86040
# Natal                                    2227
# Não Classificado                        21406
# Paranaguá - Antonina                    23873
# Pecém - Fortaleza                       12088
# Porto Alegre                            20851
# Porto Velho                             55883
# Rio Grande                              38025
# Rio de Janeiro -  Niterói               31419
# Santarém                                40219
# Santos                                  57380
# Suape - Recife                          18731
# São Francisco do Sul                    11494
# São João da Barra                       11534
# São Sebastião                            7257
# São Simão                                5319
# Tomé Açu                                  672
# Vila do Conde - Belém                   96695
# Vitória                                 31985
# Vitória do Xingu                           62
# Óbidos                                   4193
# Name: count, dtype: int64

# %%
#define o filtro de CDTUP para casar com a base de cargas de interesse
porto = 'Santos'
navegacao = 'Longo Curso'
filtro =  ANTAQ_Limpa[(ANTAQ_Limpa['Complexo Portuário'] == porto) &
                (ANTAQ_Limpa['Tipo de Navegação da Atracação'] == navegacao)]
tabela = filtro.groupby('Berço').agg({'Berço': 'count'}).rename(columns={'Berço': 'Total'})
print(tabela)
# Out:
#                                Total
# Berço
# AGEO 01                          680
# AGEO SP                            7
# AL 01                            255
# AL 02                            457
# AL 03                           1102
# AL 04                           1059
# ARM 12A                          698
# ARM 13/14                        397
# ARM 15                           696
# ARM 16/17                       1478
# ARM 19                          1230
# ARM 20/21                       1394
# ARM 22 + ARM 23                   27
# ARM 29                           423
# ARM 29/30 + ARM 30               423
# ARM 31                           696
# ARM 31/32 + ARM 32               551
# ARM 33                           228
# ARM 33/34                         15
# ARM 34                           104
# ARM 35.0                         609
# ARM 35P1                          88
# ARM 35P2                         833
# ARM 37                             1
# ARM 38                           939
# ARM 39                           955
# ARM FRIG/25                      259
# ARMAZEM 23                       496
# ARMAZÉM 17/19                      2
# ARMAZÉM 30                        79
# ARMAZÉM 31/32                    103
# ARMAZÉM 37.1                     387
# ARMAZÉM 37.2                      38
# ARMAZÉM 38/39                      1
# BTP 01                          2113
# BTP 02                          2245
# BTP 03                          1831
# Berço 1                         2090
# Berço 2                         1036
# Berço 3                          350
# Berço 4                          273
# CONCAIS                          256
# CORTE                            135
# CS 02 + CS 01                    521
# CS 03                            362
# CS 04                            485
# CS.2                             470
# Cais 2                             1
# Cais I #3                        114
# Cais I #4                        145
# Cais II #5                        87
# Cutrale                          758
# DOW                              286
# IB BC                            971
# IB SP                            853
# OUTEIRINHOS 1                     77
# OUTEIRINHOS 2 + OUTEIRINHOS 1    178
# OUTEIRINHOS 3                    418
# Pier #1                            7
# Pier #2                           37
# SUGADOR 26                        17
# TEAG                             626
# TECON 1.1                       1679
# TECON 1.2                       1427
# TECON 2                         2213
# TECON 3                         2163
# TECON 4                            3
# TEG                              812
# TERMAG                           752
# TEV                               60
# TGG                             1353
# TIP 2                            531
# TIP 3                            645
# TIP 4                            274
# TUF1                             883
# VALONGO                          647

# %%
filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46894 entries, 373 to 776076
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     46894 non-null  int64
#  1   CDTUP                           46894 non-null  object
#  2   IDBerco                         46894 non-null  object
#  3   Berço                           46894 non-null  object
#  4   Porto Atracação                 46894 non-null  object
#  5   Coordenadas                     46894 non-null  object
#  6   Apelido Instalação Portuária    3749 non-null   object
#  7   Complexo Portuário              46894 non-null  object
#  8   Tipo da Autoridade Portuária    46894 non-null  object
#  9   Data Atracação                  46894 non-null  datetime64[ns]
#  10  Data Chegada                    46894 non-null  datetime64[ns]
#  11  Data Desatracação               46894 non-null  datetime64[ns]
#  12  Data Início Operação            46894 non-null  datetime64[ns]
#  13  Data Término Operação           46894 non-null  datetime64[ns]
#  14  Ano                             46894 non-null  int64
#  15  Mes                             46894 non-null  object
#  16  Tipo de Operação                46894 non-null  object
#  17  Tipo de Navegação da Atracação  46894 non-null  object
#  18  Nacionalidade do Armador        46894 non-null  float64
#  19  FlagMCOperacaoAtracacao         46894 non-null  int64
#  20  Terminal                        46894 non-null  object
#  21  Município                       46894 non-null  object
#  22  UF                              46894 non-null  object
#  23  SGUF                            46894 non-null  object
#  24  Região Geográfica               46894 non-null  object
#  25  Nº da Capitania                 598 non-null    object
#  26  Nº do IMO                       46885 non-null  float64
#  27  Tempo_espera_chegada            46894 non-null  float64
#  28  Tempo_espera_inicial            46894 non-null  float64
#  29  Tempo_operacao                  46894 non-null  float64
#  30  Tempo_espera_final              46894 non-null  float64
#  31  Tempo_ocupacao                  46894 non-null  float64
# dtypes: datetime64[ns](5), float64(7), int64(3), object(17)
# memory usage: 11.8+ MB

# %%
colunas_interesse1 = ['IDAtracacao','CDTUP','Berço','Porto Atracação', 'Complexo Portuário','Tipo de Navegação da Atracação',
                      'Data Chegada','Data Atracação','Data Início Operação','Data Término Operação','Data Desatracação',
                      'Tempo_espera_chegada', 'Tempo_espera_inicial','Tempo_operacao', 'Tempo_espera_final', 'Tempo_ocupacao']
filtro[colunas_interesse1].to_csv(path_out + 'Atracacao_final.csv', index=False)

# %%
drive.mount('/content/drive')
arquivo = '/content/drive/My Drive/Data/Atracacao_final.csv'
with open(arquivo, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Linha 1: IDAtracacao,CDTUP,Berço,Porto Atracação,Complexo Portuário,Tipo de Navegação da Atracação,Data Chegada,Data Atracação,Data Início Operação,Data Término Operação,Data Desatracação,Tempo_espera_chegada,Tempo_espera_inicial,Tempo_operacao,Tempo_espera_final,Tempo_ocupacao
#
# Linha 2: 623855,BRSSZ,IB BC,Santos,Santos,Longo Curso,2014-06-13 08:00:00,2014-06-13 23:30:00,2014-06-14 11:00:00,2014-06-15 11:10:00,2014-06-15 15:55:00,15.5,11.5,24.166666666666668,4.75,40.416666666666664
#
# Linha 3: 623856,BRSSZ,TGG,Santos,Santos,Longo Curso,2014-06-09 08:10:00,2014-06-16 19:20:00,2014-06-16 21:20:00,2014-06-18 13:00:00,2014-06-18 21:20:00,179.16666666666666,2.0,39.666666666666664,8.333333333333334,50.0
#
# Linha 4: 623858,BRSSZ,TGG,Santos,Santos,Longo Curso,2014-06-16 00:01:00,2014-06-25 05:30:00,2014-06-25 07:10:00,2014-06-26 22:30:00,2014-06-27 01:50:00,221.48333333333332,1.6666666666666667,39.333333333333336,3.3333333333333335,44.333333333333336
#
# Linha 5: 663045,BRSSZ,OUTEIRINHOS 2 + OUTEIRINHOS 1,Santos,Santos,Longo Curso,2014-12-11 12:00:00,2014-12-11 14:55:00,2014-12-11 17:00:00,2014-12-17 00:50:00,2014-12-17 05:10:00,2.9166666666666665,2.0833333333333335,127.83333333333333,4.333333333333333,134.25

# %%
df = pd.read_csv(arquivo, low_memory=False, sep=',', encoding='UTF-8')
df.head()
# Out:
#    IDAtracacao  CDTUP                          Berço Porto Atracação  \
# 0       623855  BRSSZ                          IB BC          Santos
# 1       623856  BRSSZ                            TGG          Santos
# 2       623858  BRSSZ                            TGG          Santos
# 3       663045  BRSSZ  OUTEIRINHOS 2 + OUTEIRINHOS 1          Santos
# 4       623859  BRSSZ                            TGG          Santos
#
#   Complexo Portuário Tipo de Navegação da Atracação         Data Chegada  \
# 0             Santos                    Longo Curso  2014-06-13 08:00:00
# 1             Santos                    Longo Curso  2014-06-09 08:10:00
# 2             Santos                    Longo Curso  2014-06-16 00:01:00
# 3             Santos                    Longo Curso  2014-12-11 12:00:00
# 4             Santos                    Longo Curso  2014-06-11 21:12:00
#
#         Data Atracação Data Início Operação Data Término Operação  \
# 0  2014-06-13 23:30:00  2014-06-14 11:00:00   2014-06-15 11:10:00
# 1  2014-06-16 19:20:00  2014-06-16 21:20:00   2014-06-18 13:00:00
# 2  2014-06-25 05:30:00  2014-06-25 07:10:00   2014-06-26 22:30:00
# 3  2014-12-11 14:55:00  2014-12-11 17:00:00   2014-12-17 00:50:00
# 4  2014-06-19 01:40:00  2014-06-19 17:10:00   2014-06-22 12:00:00
#
#      Data Desatracação  Tempo_espera_chegada  Tempo_espera_inicial  \
# 0  2014-06-15 15:55:00             15.500000             11.500000
# 1  2014-06-18 21:20:00            179.166667              2.000000
# 2  2014-06-27 01:50:00            221.483333              1.666667
# 3  2014-12-17 05:10:00              2.916667              2.083333
# 4  2014-06-22 17:45:00            172.466667             15.500000
#
#    Tempo_operacao  Tempo_espera_final  Tempo_ocupacao
# 0       24.166667            4.750000       40.416667
# 1       39.666667            8.333333       50.000000
# 2       39.333333            3.333333       44.333333
# 3      127.833333            4.333333      134.250000
# 4       66.833333            5.750000       88.083333
